# %%
import ast
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
def obtain_data(csv_file_path,mission_name):
    df = pd.read_csv(csv_file_path)
    df1 =df.set_index('name')

    score1 = df1.loc[f'{mission_name}_100%']['score']
    data1 = ast.literal_eval(score1)

    score2 = df1.loc[f'{mission_name}_80%']['score']
    data2 = ast.literal_eval(score2)

    score3 = df1.loc[f'{mission_name}_60%']['score']
    data3 = ast.literal_eval(score3)

    score4 = df1.loc[f'{mission_name}_40%']['score']
    data4 = ast.literal_eval(score4)

    score5 = df1.loc[f'{mission_name}_20%']['score']
    data5 = ast.literal_eval(score5)
    
    return [data1,data2,data3,data4,data5]

# %%
def plot_data(data, plot_title):
    plt.boxplot(data, notch=True)
    plt.ticklabel_format(style='plain', axis='y', scilimits=(0,0))
    plt.title(plot_title, fontsize=20, family='sans-serif', pad=30)
    plt.xticks(np.array([1,2,3,4,5]),['100%', '80%','60%','40%','20%'], fontsize=15)
    plt.yticks(fontsize=15)
    # plt.savefig("boxplot_aac.png", bbox_inches='tight')

# %%
[data1,data2,data3,data4,data5] = obtain_data(csv_file_path = 'score.csv', mission_name='aggregation_tutti')
plot_data([data1,data2,data3,data4,data5], 'Agreggation Tuttifrutti')

# %%
[data1,data2,data3,data4,data5] = obtain_data(csv_file_path = 'score.csv', mission_name='aggregation_habanero')
plot_data([data1,data2,data3,data4,data5], 'Agreggation Habanero')

# %%
[data1,data2,data3,data4,data5] = obtain_data(csv_file_path = 'score.csv', mission_name='homing_habanero')
plot_data([data1,data2,data3,data4,data5], 'Homing Habanero')

# %%
[data1,data2,data3,data4,data5] = obtain_data(csv_file_path = 'score.csv', mission_name='homing_tutti')
plot_data([data1,data2,data3,data4,data5], 'Homing Tuttifrutti')

# %%
[data1,data2,data3,data4,data5] = obtain_data(csv_file_path = 'score.csv', mission_name='tasking_habanero')
plot_data([data1,data2,data3,data4,data5], 'Tasking Habanero')

# %%
[data1,data2,data3,data4,data5] = obtain_data(csv_file_path = 'score.csv', mission_name='tasking_tutti')
plot_data([data1,data2,data3,data4,data5], 'Tasking Tuttifrutti')
